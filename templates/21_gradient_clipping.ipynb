# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/21_gradient_clipping.ipynb)
#
# # 🟢 Easy: Gradient Norm Clipping
#
# Implement **gradient norm clipping** — a training stability technique.
#
# ### Signature
# ```python
# def clip_grad_norm(parameters, max_norm: float) -> float:
#     # Clip gradients in-place so total norm <= max_norm
#     # Returns the original (unclipped) total norm
# ```
#
# ### Algorithm
# 1. Compute total norm: `sqrt(sum(p.grad.norm()^2 for p in parameters))`
# 2. If total > max_norm: scale all grads by `max_norm / total`
# 3. Return original total norm

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def clip_grad_norm(parameters, max_norm):
  total_norm = math.sqrt( sum( (p.grad.norm(2)) ** 2 for p in parameters if p is not None ) )
  if total_norm > max_norm:
    p.grad * max_norm / (total_norm+1e-6)
  else:
    return total_norm
  return total_norm

  # pass  # compute total norm, clip if needed, return original norm

# %%
# 🧪 Debug
p = torch.randn(100, requires_grad=True)
(p * 10).sum().backward()
print('Before:', p.grad.norm().item())
orig = clip_grad_norm([p], max_norm=1.0)
print('After: ', p.grad.norm().item())
print('Original norm:', orig)
# Out:
# Before: 100.0
# After:  100.0
# Original norm: 100.0

# %%
# ✅ SUBMIT
from torch_judge import check, hint
hint('gradient_clipping')
check('gradient_clipping')
# Out:
# 💡 Hint for Gradient Norm Clipping:
#    Total norm = sqrt(sum(p.grad.norm()^2)). If total > max_norm, scale all grads by max_norm/total. Return original total norm.
#
#
# 🧪 Testing: Gradient Norm Clipping (Easy)
# ──────────────────────────────────────────────────
#   ❌ [1/4] Clips to max_norm
#      Clipped norm 44.7214 > 1.0
#   ✅ [2/4] Returns original norm (1.6ms)
#   ✅ [3/4] No change when norm < max_norm (0.9ms)
#   ✅ [4/4] Preserves direction (1.6ms)
# ──────────────────────────────────────────────────
#   📊 3/4 tests passed.
#   Keep going! Use hint("gradient_clipping") if you're stuck.
